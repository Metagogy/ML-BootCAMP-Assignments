# %% [markdown]
# ### Question:
# Build, compile, train and evaluate multilayer perceptron model by making your own dataset of classification using from sklearn.datasets import make_gaussian_quantiles and use SGD as optimizer and loss as binary cross entropy.

# %% [markdown]
# ### Description :
#
# Develop a Multilayer Perceptron model for dataset.
#
# generate 2d classification dataset with
#
#
# from sklearn.datasets import make_gaussian_quantiles
#
# X1, y1 = make_gaussian_quantiles(cov=3.,
#                                  n_samples=10000, n_features=2,
#                                  n_classes=3, random_state=1)
#
# Split the model by using training and testing
#
# Build the model by using the Sequential model and adding the first activation as relu layer having 5 neurons and the second
#
# activation function as a sigmoid layer having 1 neuron
#
# Compile the model by using SGD optimizer and loss has binary_cross entropy
#
# Fit or train the model by using with training, validation data, 500 Epochs, and 0 verbose
#
# get result of  model with train and test values

# %% [markdown]
# ### Explanation :
# A dense layer is just a regular layer of neurons in a neural network. Each neuron receives input from all the neurons in the previous layer, thus densely connected. The layer has a weight matrix W, a bias vector b, and the activations of the previous layer a.
#
# Compile defines the loss function, the optimizer, and the metrics.
#
# model.fit() used to train our built model.
#
# evaluate() is for evaluating your trained model. Its output is accuracy or loss, not a prediction of your input data.
#
# print the acuuracy of test and train of the model

# %% [markdown]
# ### Library :
#     [tensorflow/keras/layers/models/optimizers/initializers/matplotlib/sklearn]
# ### Category:
#     Machine Learning

# %% [markdown]
# ### Input format :
# Dataset

# %% [markdown]
# ### Output format :
# Model accuracy and visualization

# %% [markdown]
# ### Sample Input :
# Load given data

# %% [markdown]
# ### Sample Output :
# Train: 0.957, Test: 0.633

# %%
from sklearn.datasets import make_gaussian_quantiles

# %%
X1, y1 = make_gaussian_quantiles(cov=2.,n_samples=100, n_features=10,n_classes=2, random_state=1)

# %%
X1
# Out:
# array([[-6.31728072e-01,  2.89033284e-01,  8.65827538e-01,
#          1.05342581e+00, -5.13094903e-02, -1.17718479e+00,
#          2.72068587e+00, -8.56987002e-01,  2.55066000e+00,
#         -6.39966955e-01],
#        [-3.98435253e-01,  2.90812587e+00,  2.48936833e+00,
#         -8.57755765e-02, -3.41320868e+00, -2.51385848e+00,
#         -1.10005850e+00,  1.57803763e+00,  4.38791277e-01,
#         -2.96171366e+00],
#        [-2.51209861e-01, -2.13610789e+00,  1.43006274e+00,
#         -2.08817494e+00, -2.02509365e-01,  1.46085967e+00,
#         -3.14540936e-01,  2.07912070e+00, -1.23037743e+00,
#          5.22114169e-01],
#        [-5.66927376e-01,  1.16531992e+00, -7.95219967e-01,
#          2.76461509e+00, -1.88366411e+00, -2.48998964e+00,
#         -2.33447240e+00, -1.25943579e+00, -1.58266817e+00,
#          2.76631331e+00],
#        [ 3.09187201e-02, -6.62804867e-01,  1.20672188e+00,
#         -5.84111651e-01,  2.59468255e+00,  7.98157889e-01,
#          3.02334545e+00, -1.11091283e+00, -2.48325385e+00,
#          1.01086514e+00],
#        [ 2.04053612e+00, -7.63224985e-01,  1.81552481e-01,
#          2.48960303e+00,  1.36689292e+00,  1.00840364e+00,
#          1.84725433e+00, -8.55037719e-01,  9.00264891e-01,
#          1.99298526e+00],
#        [-4.38571347e-01, -3.44338059e+00,  1.46911984e+00,
#          3.09285628e+00,  6.24183582e-01, -1.41640889e-01,
#         -1.92962007e-01, -1.68368047e-01,  2.46206213e-02,
#         -1.58677410e+00],
#        [ 1.20590565e+00,  5.00067288e-02, -2.17618228e+00,
#         -6.33419445e-01,  8.73963523e-01, -2.60464658e-01,
#         -1.64027822e-01, -2.48136453e-01, -1.32075477e+00,
#         -7.53804574e-01],
#        [ 2.06773287e+00, -2.91347893e+00, -4.55966783e-01,
#         -5.43134877e-01,  1.60339212e+00, -1.55548115e+00,
#         -2.43850310e-01, -1.24147928e+00,  5.96992531e-02,
#          8.24225180e-01],
#        [-1.38277984e+00,  2.43184108e-01,  6.93758081e-01,
#         -1.97322818e+00, -7.38723597e-01, -5.22206704e-01,
#          3.75675088e-01, -3.68354633e-01,  6.29461804e-01,
#          1.38751669e-01],
#        [-1.50557348e-01, -3.94706497e+00, -6.45047633e-01,
#         -1.38577408e+00,  9.79448035e-01, -6.76944938e-01,
#         -4.65349164e-01,  1.90509482e+00, -1.48360583e+00,
#          4.47823304e-01],
#        [ 1.36644265e+00,  1.02660146e+00,  4.69671462e+00,
#         -8.48846803e-01, -5.36718818e-01, -1.43514914e+00,
#          6.16577592e-01, -9.72253995e-01, -3.81605977e+00,
#         -1.71591923e+00],
#        [ 1.64230598e+00,  1.51315978e+00, -1.47860871e+00,
#          5.02448168e-01,  1.06828565e+00,  9.91338423e-01,
#         -2.81340040e-01,  4.27035992e-01, -5.58175500e-01,
#         -1.65719437e+00],
#        [-1.55651057e+00,  1.61888380e+00,  1.27504182e+00,
#          7.10634309e-01,  1.27400270e+00, -9.66937211e-01,
#         -1.73793024e-01, -1.32337783e+00, -3.78850955e-01,
#          7.50035894e-01],
#        [-3.48136329e-02, -1.09624407e+00,  1.80136291e+00,
#          2.78190197e+00, -2.62758315e+00,  1.74819994e+00,
#          2.30184577e+00,  4.78020726e-01, -1.69602112e+00,
#          1.22095466e+00],
#        [-1.52835572e+00,  1.02597518e+00, -5.54064213e-02,
#         -3.23507251e-01, -2.54010143e-01,  7.09546454e-01,
#         -8.39114784e-01,  7.21683924e-01, -1.29512525e+00,
#         -5.75941363e-01],
#        [ 6.19660791e-01,  1.58721193e+00, -1.40999892e+00,
#         -1.51029504e-01,  2.05263095e+00, -8.74036092e-01,
#         -2.88103760e+00, -2.74723597e+00, -3.54464236e+00,
#         -2.98987929e+00]])

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.initializers import RandomUniform

# generate 2d classification dataset
X, y = make_gaussian_quantiles(cov=2.,n_samples=100, n_features=10,n_classes=2, random_state=1)
# split into train and test
n_train = 70
trainX, testX = X[:n_train, :], X[n_train:, :]
trainy, testy = y[:n_train], y[n_train:]
# define model
model = tf.keras.Sequential()
init = RandomUniform(minval=0, maxval=1)
model.add(tf.keras.layers.Dense(5, input_dim=10, activation='relu', kernel_initializer=init))
model.add(tf.keras.layers.Dense(1, activation='sigmoid', kernel_initializer=init))

# compile model
opt = SGD(lr=0.01, momentum=0.9)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
# fit model
history = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=500, verbose=0)
# evaluate the model
_, train_acc = model.evaluate(trainX, trainy, verbose=0)
_, test_acc = model.evaluate(testX, testy, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# plot training history
#pyplot.plot(history.history['accuracy'], label='train')
#pyplot.plot(history.history['val_accuracy'], label='test')
#pyplot.legend()
#pyplot.show()
# Out:
# Train: 0.957, Test: 0.633
